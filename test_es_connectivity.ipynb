# %% [markdown]
# To run this notebook, you will need to install: pandas, openai, transformers, plotly, matplotlib, scikit-learn, torch (transformer dep), torchvision, and scipy.

# %%
import os
from dotenv import load_dotenv
from elasticsearch import Elasticsearch

# %%
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Get values from .env
ES_HOST = os.getenv("ES_HOST")
ES_USERNAME = os.getenv("ES_USERNAME")
ES_PASSWORD = os.getenv("ES_PASSWORD")

# Connect to Elasticsearch
es = Elasticsearch(
    hosts=[ES_HOST],
    basic_auth=(ES_USERNAME, ES_PASSWORD),
    verify_certs=False  # Set to True if you're using HTTPS with a valid cert
)

# Optional: Test connection
try:
    info = es.info()
    print("Connected to Elasticsearch:", info['cluster_name'])
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connected to Elasticsearch: 5f7549915f6a4e0caaac633b0d2523ee
# /Users/dks0802651/.pyenv/versions/3.10.13/envs/vector_search_310/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'dsg-search-dev-east.es.eastus.azure.elastic-cloud.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
